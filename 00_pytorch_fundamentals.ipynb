# %% [markdown]
# <a href="https://colab.research.google.com/github/AdewaleOpeloyeru/learnpytorch/blob/colab-commits/00_pytorch_fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 00. PyTorch Fundamentals
# Resource notebook: https://www.learnpytorch.io/00_pytorch_fundamentals/
#
# Questions: https://github.com/mrdbourke/pytorch-deep-learning/discussions

# %%
print("Hello. I'm excited to learn PyTorch!")
# Out:
# Hello. I'm excited to learn PyTorch!

# %%
# !nvidia-smi
# Out:
# /bin/bash: line 1: nvidia-smi: command not found

# %%
import torch
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
print(torch.__version__)
# Out:
# 2.9.0+cpu

# %% [markdown]
# ## Introduction to Tensors
# ### Creating Tensors
# PyTorch tensors are created using torch.Tensor() ==> https://docs.pytorch.org/docs/stable/tensors.html

# %%
# scalar
scalar = torch.tensor(7)
scalar
# Out:
# tensor(7)

# %%
# Get tensor back as python int
scalar.item() # returns scalar equivalent. doesn't work with tensors of dimension greater than 0
# Out:
# 7

# %%
scalar.ndim    #ndim = dimension
# Out:
# 0

# %%
# Vector
vector = torch.tensor([7, 7])
vector
# Out:
# tensor([7, 7])

# %%
vector.ndim   # ndim contains how many dimensions a tensor has. e.g vector only has columns so it has 1 dimension
# Out:
# 1

# %%
vector.shape    # Returns how many elements are in each dimension. i.e; we have 2 elements in vector
# Out:
# torch.Size([2])

# %%
# MATRIX
MATRIX = torch.tensor([[7, 8],[9, 10]])
MATRIX
# Out:
# tensor([[ 7,  8],
#         [ 9, 10]])

# %%
MATRIX.ndim     # i.e we have rows and columns
# Out:
# 2

# %%
MATRIX[1]
# Out:
# tensor([ 9, 10])

# %%
MATRIX.shape          # 2 element per row and 2 elements per column
# Out:
# torch.Size([2, 2])

# %%
# TENSOR
TENSOR = torch.tensor([[[1,2,3],
                        [3,6,9],
                        [2,4,5]]])

TENSOR
# Out:
# tensor([[[1, 2, 3],
#          [3, 6, 9],
#          [2, 4, 5]]])

# %%
TENSOR.ndim
# Out:
# 3

# %%
TENSOR.shape
# Out:
# torch.Size([1, 3, 3])

# %%
TENSOR[0]
# Out:
# tensor([[1, 2, 3],
#         [3, 6, 9],
#         [2, 4, 5]])

# %%
# Note that a tensor can have any dimension. A matrix/tensor is usually defined as uppercase letters
MYTENSOR =  torch.tensor([[[1,2,3],
                        [3,6,9],
                        [2,4,5]],
                          [[-1,-2,-3],
                           [-3,-6,-3],
                           [-2,-4,-5]]])
MYTENSOR
# Out:
# tensor([[[ 1,  2,  3],
#          [ 3,  6,  9],
#          [ 2,  4,  5]],
#
#         [[-1, -2, -3],
#          [-3, -6, -3],
#          [-2, -4, -5]]])

# %%
MYTENSOR.ndim
# Out:
# 3

# %%
MYTENSOR.shape
# Out:
# torch.Size([2, 3, 3])

# %% [markdown]
# ### Random Tensors
#
# WHy random tensors?
#
# Random tensors are important because the way many neural networks learn is that the strat with tensors full of random numbers and then adjust those random numbers to better represent the data.
#
# `Start with random numbers -> look at data -> update random numbers -> look at data -> update random numbers`
#
# random tensors: https://docs.pytorch.org/docs/stable/generated/torch.rand.html

# %%
# Create random tensor of  size (3, 4)
random_tensor = torch.rand(3,4)
random_tensor
# Out:
# tensor([[0.0239, 0.6480, 0.0286, 0.8837],
#         [0.5510, 0.8512, 0.1899, 0.8131],
#         [0.0839, 0.1943, 0.3189, 0.0114]])

# %%
random_tensor.ndim
# Out:
# 2

# %%
ANOTHERTENSOR = torch.rand(10,10,10)
ANOTHERTENSOR
# Out:
# tensor([[[0.8468, 0.1809, 0.5701, 0.7096, 0.5840, 0.7439, 0.7491, 0.2314,
#           0.7366, 0.6903],
#          [0.3360, 0.5056, 0.4014, 0.1540, 0.8997, 0.8774, 0.0740, 0.4133,
#           0.5382, 0.0350],
#          [0.1448, 0.9719, 0.3960, 0.7346, 0.7426, 0.2328, 0.3487, 0.5473,
#           0.3868, 0.4794],
#          [0.5355, 0.6351, 0.8234, 0.7413, 0.3002, 0.3978, 0.3310, 0.4348,
#           0.1535, 0.7622],
#          [0.9557, 0.9417, 0.4846, 0.6911, 0.6639, 0.0828, 0.0308, 0.3405,
#           0.5908, 0.9159],
#          [0.7053, 0.6634, 0.6068, 0.8975, 0.4516, 0.8334, 0.9039, 0.2500,
#           0.5264, 0.4144],
#          [0.0366, 0.7978, 0.7620, 0.1935, 0.0637, 0.7047, 0.4282, 0.0201,
#           0.7632, 0.7482],
#          [0.5326, 0.0444, 0.7059, 0.2973, 0.0583, 0.4168, 0.6002, 0.0478,
#           0.7040, 0.1692],
#          [0.5067, 0.7791, 0.8887, 0.9624, 0.2155, 0.2252, 0.9183, 0.8110,
#           0.9581, 0.8503],
#          [0.2356, 0.2585, 0.1747, 0.0373, 0.5084, 0.4108, 0.6253, 0.2463,
#           0.9499, 0.6593]],
#
#         [[0.0132, 0.3879, 0.3255, 0.7558, 0.0447, 0.1099, 0.2411, 0.7341,
#           0.4483, 0.3763],
#          [0.6038, 0.9826, 0.4099, 0.9363, 0.4373, 0.8165, 0.7619, 0.0815,
#           0.4718, 0.1888],
#          [0.0670, 0.3342, 0.8203, 0.2862, 0.1029, 0.6386, 0.2504, 0.5030,
#           0.0089, 0.5648],
#          [0.7494, 0.1196, 0.5121, 0.1498, 0.8218, 0.4316, 0.2030, 0.2285,
#           0.6081, 0.3774],
#          [0.6393, 0.3441, 0.2971, 0.1437, 0.4956, 0.5735, 0.2453, 0.1843,
#           0.2764, 0.6996],
#          [0.7465, 0.6107, 0.6086, 0.2031, 0.5252, 0.6695, 0.3129, 0.5149,
#           0.7577, 0.1445],
#          [0.8770, 0.8437, 0.9972, 0.6167, 0.5914, 0.9919, 0.9894, 0.3386,
#           0.5419, 0.9541],
#          [0.9160, 0.2671, 0.7320, 0.5791, 0.2275, 0.5172, 0.5300, 0.0466,
#           0.2986, 0.7923],
#          [0.9594, 0.5119, 0.4389, 0.9112, 0.4902, 0.9004, 0.1035, 0.1238,
#           0.9866, 0.3800],
#          [0.2907, 0.2746, 0.5898, 0.1632, 0.0622, 0.3161, 0.1098, 0.1547,
#           0.2048, 0.4258]],
#
#         [[0.7769, 0.0450, 0.8143, 0.0396, 0.5595, 0.0230, 0.1571, 0.0779,
#           0.6975, 0.1920],
#          [0.3948, 0.0401, 0.9278, 0.1578, 0.1749, 0.9423, 0.5007, 0.8952,
#           0.5551, 0.6165],
#          [0.5403, 0.2851, 0.7248, 0.9149, 0.2493, 0.8519, 0.1566, 0.4230,
#           0.8948, 0.9803],
#          [0.0529, 0.0626, 0.6054, 0.5867, 0.9158, 0.4420, 0.8664, 0.3261,
#           0.0553, 0.2015],
#          [0.3429, 0.0429, 0.2518, 0.5697, 0.0776, 0.7390, 0.4729, 0.1239,
#           0.8475, 0.4193],
#          [0.1627, 0.9596, 0.6438, 0.1381, 0.0388, 0.7553, 0.0713, 0.1442,
#           0.7468, 0.8886],
#          [0.0144, 0.3579, 0.1031, 0.1455, 0.2185, 0.4133, 0.4376, 0.9292,
#           0.2733, 0.5325],
#          [0.9969, 0.3345, 0.3664, 0.9918, 0.2251, 0.8731, 0.5545, 0.0287,
#           0.0179, 0.7923],
#          [0.6804, 0.3064, 0.5436, 0.2402, 0.1626, 0.1798, 0.9139, 0.8583,
#           0.8605, 0.5133],
#          [0.3018, 0.1251, 0.7542, 0.5684, 0.2577, 0.6943, 0.1916, 0.9169,
#           0.7992, 0.6904]],
#
#         [[0.3323, 0.6180, 0.6764, 0.1762, 0.8590, 0.6346, 0.5409, 0.6532,
#           0.3956, 0.6968],
#          [0.4313, 0.5928, 0.6551, 0.2339, 0.8988, 0.7860, 0.6791, 0.5982,
#           0.8902, 0.4889],
#          [0.0171, 0.0266, 0.6402, 0.6471, 0.8376, 0.2735, 0.6648, 0.7736,
#           0.0447, 0.4573],
#          [0.8802, 0.2430, 0.5652, 0.3173, 0.9761, 0.5299, 0.7692, 0.6885,
#           0.3513, 0.8318],
#          [0.3533, 0.5867, 0.2116, 0.4802, 0.5083, 0.9881, 0.6223, 0.2458,
#           0.1388, 0.7350],
#          [0.2986, 0.0624, 0.3337, 0.6453, 0.4052, 0.4257, 0.7690, 0.1656,
#           0.3890, 0.3494],
#          [0.4269, 0.5486, 0.0584, 0.1013, 0.7392, 0.0279, 0.5166, 0.1103,
#           0.6383, 0.4876],
#          [0.6802, 0.7357, 0.6797, 0.6711, 0.8685, 0.8124, 0.8062, 0.0624,
#           0.5893, 0.6397],
#          [0.0776, 0.4269, 0.2322, 0.3775, 0.9579, 0.6452, 0.4706, 0.1847,
#           0.3994, 0.5885],
#          [0.5932, 0.2757, 0.5129, 0.9243, 0.0126, 0.1222, 0.3487, 0.7557,
#           0.0944, 0.4987]],
#
#         [[0.4688, 0.1610, 0.2386, 0.0623, 0.4291, 0.3219, 0.6707, 0.2728,
#           0.5262, 0.8352],
#          [0.2114, 0.7906, 0.9490, 0.2491, 0.4653, 0.8262, 0.6553, 0.9863,
#           0.3817, 0.3702],
#          [0.3204, 0.4764, 0.3342, 0.8161, 0.1805, 0.7783, 0.2055, 0.9791,
#           0.8725, 0.6671],
#          [0.7003, 0.3966, 0.1006, 0.6942, 0.0949, 0.1194, 0.5220, 0.7114,
#           0.4192, 0.3340],
#          [0.9013, 0.8143, 0.3965, 0.0165, 0.4099, 0.4655, 0.1428, 0.6487,
#           0.3190, 0.5333],
#          [0.9236, 0.7022, 0.5590, 0.8510, 0.5713, 0.9939, 0.7129, 0.9927,
#           0.8116, 0.2066],
#          [0.2125, 0.1970, 0.2297, 0.8778, 0.7664, 0.0651, 0.3267, 0.0721,
#           0.1212, 0.7728],
#          [0.9773, 0.8162, 0.5088, 0.7237, 0.6482, 0.1277, 0.0417, 0.2772,
#           0.0590, 0.5463],
#          [0.7468, 0.4292, 0.9643, 0.5929, 0.2053, 0.5921, 0.7608, 0.7428,
#           0.4220, 0.0828],
#          [0.5833, 0.2043, 0.8848, 0.7364, 0.4144, 0.7141, 0.8205, 0.5709,
#           0.9102, 0.1346]],
#
#         [[0.9377, 0.4991, 0.5251, 0.1826, 0.9786, 0.8748, 0.7612, 0.2294,
#           0.3772, 0.7923],
#          [0.7841, 0.3969, 0.7927, 0.3230, 0.6263, 0.0652, 0.7062, 0.4464,
#           0.7189, 0.7349],
#          [0.9803, 0.6663, 0.9703, 0.9023, 0.4619, 0.5355, 0.1077, 0.8992,
#           0.3175, 0.9929],
#          [0.9883, 0.3451, 0.5626, 0.4401, 0.9608, 0.0680, 0.1527, 0.9414,
#           0.2108, 0.5126],
#          [0.0692, 0.8185, 0.7220, 0.9305, 0.3275, 0.8413, 0.8233, 0.6996,
#           0.0304, 0.5158],
#          [0.9783, 0.3493, 0.2399, 0.8464, 0.4664, 0.2286, 0.6216, 0.0268,
#           0.3772, 0.0462],
#          [0.6125, 0.1742, 0.9249, 0.0718, 0.4848, 0.6783, 0.7700, 0.3483,
#           0.8589, 0.6498],
#          [0.0435, 0.2768, 0.3238, 0.9784, 0.7898, 0.0344, 0.0143, 0.3171,
#           0.7619, 0.3708],
#          [0.8311, 0.1133, 0.8115, 0.6941, 0.0073, 0.2780, 0.6460, 0.9187,
#           0.0877, 0.4797],
#          [0.8528, 0.7481, 0.3807, 0.9135, 0.4427, 0.9534, 0.9784, 0.0550,
#           0.9148, 0.8589]],
#
#         [[0.5252, 0.3766, 0.7247, 0.9872, 0.8787, 0.2931, 0.2061, 0.6825,
#           0.7226, 0.6415],
#          [0.6711, 0.5332, 0.0255, 0.0361, 0.3042, 0.7179, 0.3313, 0.3074,
#           0.7880, 0.6666],
#          [0.6477, 0.1841, 0.0033, 0.3234, 0.9825, 0.8030, 0.6009, 0.9683,
#           0.5063, 0.6490],
#          [0.1580, 0.8297, 0.6470, 0.5866, 0.9885, 0.6944, 0.3807, 0.5145,
#           0.8787, 0.4209],
#          [0.3137, 0.9655, 0.5293, 0.8706, 0.6898, 0.8214, 0.7083, 0.7668,
#           0.3460, 0.7357],
#          [0.4391, 0.3852, 0.7495, 0.7677, 0.0720, 0.2417, 0.3672, 0.9429,
#           0.7916, 0.1365],
#          [0.3588, 0.7045, 0.8540, 0.8795, 0.9793, 0.8570, 0.5777, 0.4859,
#           0.6048, 0.2251],
#          [0.2848, 0.4435, 0.5384, 0.7448, 0.8618, 0.7168, 0.1788, 0.7072,
#           0.9636, 0.5691],
#          [0.2884, 0.7155, 0.1565, 0.3652, 0.9974, 0.9621, 0.7519, 0.4673,
#           0.5928, 0.7234],
#          [0.6088, 0.0666, 0.7187, 0.3666, 0.1909, 0.1664, 0.8334, 0.9818,
#           0.0846, 0.9412]],
#
#         [[0.6817, 0.0566, 0.4413, 0.0491, 0.7054, 0.2315, 0.9170, 0.2206,
#           0.1752, 0.6834],
#          [0.0616, 0.1812, 0.1314, 0.8823, 0.3332, 0.3808, 0.3258, 0.5022,
#           0.8963, 0.8040],
#          [0.8493, 0.9014, 0.8939, 0.4593, 0.4318, 0.5635, 0.0357, 0.7579,
#           0.0850, 0.0312],
#          [0.1109, 0.3211, 0.5613, 0.9067, 0.6003, 0.6450, 0.9438, 0.6679,
#           0.7327, 0.2926],
#          [0.8581, 0.5407, 0.9049, 0.9995, 0.6892, 0.0760, 0.6579, 0.9659,
#           0.2080, 0.2430],
#          [0.8453, 0.7739, 0.1761, 0.8982, 0.6174, 0.9934, 0.6201, 0.7378,
#           0.0594, 0.9067],
#          [0.2187, 0.3587, 0.3880, 0.4852, 0.4958, 0.3404, 0.3556, 0.1184,
#           0.0833, 0.8930],
#          [0.7318, 0.4965, 0.4762, 0.6174, 0.8363, 0.4598, 0.2566, 0.8614,
#           0.4650, 0.0873],
#          [0.0459, 0.7147, 0.3759, 0.6516, 0.8474, 0.5857, 0.9311, 0.7743,
#           0.7209, 0.0207],
#          [0.7660, 0.4285, 0.7191, 0.3131, 0.0722, 0.6455, 0.9379, 0.1352,
#           0.2955, 0.5351]],
#
#         [[0.5473, 0.9017, 0.1990, 0.6251, 0.2255, 0.1124, 0.8438, 0.8273,
#           0.6691, 0.7141],
#          [0.1514, 0.9206, 0.0251, 0.8561, 0.0046, 0.7767, 0.5753, 0.2740,
#           0.0776, 0.5497],
#          [0.4713, 0.4054, 0.8966, 0.7395, 0.3346, 0.6489, 0.3091, 0.2844,
#           0.4153, 0.1233],
#          [0.4318, 0.6219, 0.4532, 0.5659, 0.0224, 0.7417, 0.1674, 0.5680,
#           0.8057, 0.4499],
#          [0.9783, 0.9439, 0.0620, 0.5218, 0.3631, 0.3710, 0.4361, 0.3040,
#           0.7208, 0.6296],
#          [0.3815, 0.0134, 0.4233, 0.7005, 0.3711, 0.5849, 0.6559, 0.8597,
#           0.3350, 0.0494],
#          [0.5069, 0.2055, 0.3854, 0.1776, 0.7394, 0.3652, 0.2319, 0.0120,
#           0.4586, 0.5913],
#          [0.8840, 0.3561, 0.7095, 0.4094, 0.7091, 0.1472, 0.9502, 0.8738,
#           0.9481, 0.9593],
#          [0.2123, 0.0894, 0.5575, 0.2842, 0.2994, 0.7075, 0.1026, 0.5990,
#           0.6238, 0.3270],
#          [0.8323, 0.5230, 0.2199, 0.4543, 0.1186, 0.6738, 0.9042, 0.6974,
#           0.1846, 0.5482]],
#
#         [[0.3502, 0.6742, 0.5057, 0.5344, 0.3725, 0.0471, 0.5456, 0.8745,
#           0.5464, 0.8198],
#          [0.3768, 0.8428, 0.1720, 0.5510, 0.3467, 0.0625, 0.0583, 0.7319,
#           0.9678, 0.1434],
#          [0.6941, 0.2976, 0.5594, 0.0973, 0.8975, 0.5503, 0.6782, 0.5589,
#           0.9826, 0.6372],
#          [0.7118, 0.6235, 0.1349, 0.3555, 0.7640, 0.6558, 0.0278, 0.8169,
#           0.9142, 0.8279],
#          [0.0759, 0.4835, 0.7223, 0.6295, 0.0193, 0.1194, 0.4772, 0.8712,
#           0.7658, 0.9936],
#          [0.3375, 0.9659, 0.1977, 0.7546, 0.0507, 0.1461, 0.8765, 0.2777,
#           0.8617, 0.4960],
#          [0.1938, 0.5495, 0.0940, 0.5576, 0.2136, 0.9896, 0.5440, 0.8166,
#           0.0216, 0.1845],
#          [0.6572, 0.4577, 0.4711, 0.3384, 0.1930, 0.0881, 0.3326, 0.2753,
#           0.6099, 0.4287],
#          [0.1474, 0.9282, 0.2089, 0.9319, 0.2511, 0.2679, 0.8524, 0.0358,
#           0.2840, 0.1795],
#          [0.5458, 0.0160, 0.1132, 0.2428, 0.5787, 0.8493, 0.2965, 0.1798,
#           0.4165, 0.7900]]])

# %%
ANOTHERTENSOR.ndim, ANOTHERTENSOR.shape
# Out:
# (3, torch.Size([10, 10, 10]))

# %%
# Create a random tensor with similar shape to an image tensor
random_image_tensor = torch.rand(size=(224, 224, 3)) # height, width, colour channel
random_image_tensor.shape, random_image_tensor.ndim
# Out:
# (torch.Size([224, 224, 3]), 3)
